# %% [markdown]
# <a href="https://colab.research.google.com/github/sln2737/AGE/blob/master/SpeakerProfiling_TIMIT.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Dataset

# %% [markdown]
# ## Download the Timit Dataset

# %%
# !wget https://data.deepai.org/timit.zip
# !mkdir dataset
# !unzip timit.zip -d 'dataset'
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: dataset/data/TRAIN/DR6/MTXS0/SA1.WAV
#   inflating: dataset/data/TRAIN/DR6/MTXS0/SA1.WAV.wav
#   inflating: dataset/data/TRAIN/DR6/MTXS0/SA1.WRD
#   inflating: dataset/data/TRAIN/DR6/MTXS0/SA2.PHN
#   inflating: dataset/data/TRAIN/DR6/MTXS0/SA2.TXT
#   inflating: dataset/data/TRAIN/DR6/MTXS0/SA2.WAV
#   inflating: dataset/data/TRAIN/DR6/MTXS0/SA2.WAV.wav
#   inflating: dataset/data/TRAIN/DR6/MTXS0/SA2.WRD
#   inflating: dataset/data/TRAIN/DR6/MTXS0/SI1060.PHN
#   inflating: dataset/data/TRAIN/DR6/MTXS0/SI1060.TXT
#   inflating: dataset/data/TRAIN/DR6/MTXS0/SI1060.WAV
#   inflating: dataset/data/TRAIN/DR6/MTXS0/SI1060.WAV.wav
#   inflating: dataset/data/TRAIN/DR6/MTXS0/SI1060.WRD
#   inflating: dataset/data/TRAIN/DR6/MTXS0/SI1690.PHN
#   inflating: dataset/data/TRAIN/DR6/MTXS0/SI1690.TXT
#   inflating: dataset/data/TRAIN/DR6/MTXS0/SI1690.WAV
#   inflating: dataset/data/TRAIN/DR6/MTXS0/SI1690.WAV.wav
# ...

# %% [markdown]
# ## Clone the repository

# %%
# !git clone https://github.com/shangeth/SpeakerProfiling.git
# Out:
# Cloning into 'SpeakerProfiling'...
# remote: Enumerating objects: 173, done.
# remote: Counting objects: 100% (173/173), done.
# remote: Compressing objects: 100% (109/109), done.
# remote: Total 173 (delta 99), reused 115 (delta 58), pack-reused 0
# Receiving objects: 100% (173/173), 130.20 KiB | 21.70 MiB/s, done.
# Resolving deltas: 100% (99/99), done.

# %%
# !pip install -r SpeakerProfiling/requirements.txt
# Out:
# ...
#      |████████████████████████████████| 1.9MB 16.0MB/s
# ...
#      |████████████████████████████████| 849kB 51.5MB/s
# ...
#      |████████████████████████████████| 81kB 10.9MB/s
# ...
#      |████████████████████████████████| 1.7MB 53.5MB/s
# ...
#      |████████████████████████████████| 112kB 58.0MB/s
# ...
#      |████████████████████████████████| 276kB 55.2MB/s
# ...
#      |████████████████████████████████| 184kB 55.2MB/s
# ...
#      |████████████████████████████████| 829kB 52.0MB/s
# ...
#      |████████████████████████████████| 61kB 9.4MB/s
# ...
#      |████████████████████████████████| 133kB 57.1MB/s
# ...
#      |████████████████████████████████| 1.3MB 44.5MB/s
# ...
#      |████████████████████████████████| 112kB 62.2MB/s
# ...
#      |████████████████████████████████| 143kB 55.1MB/s
# ...
#      |████████████████████████████████| 296kB 55.1MB/s
# ...
#   Created wheel for PyYAML: filename=PyYAML-5.3.1-cp37-cp37m-linux_x86_64.whl size=44620 sha256=c8348fcdebce4626d844500ae63a83cd40e43c999bc6d5bb7aa60e9c6c0d84f9
# ...

# %% [markdown]
# ## Download noise Dataset

# %%
mkdir noise_dataset

# %%
import wavencoder
wavencoder.utils.download_noise_dataset('noise_dataset', sample_rate='16k', download_all=True)
# Out:
# ...
# noise_dataset/DKITCHEN_16k.zip: 111MB [00:08, 13.3MB/s]
# Extracting noise files for - (kitchen)
# ...
# noise_dataset/DLIVING_16k.zip: 80.2MB [00:09, 8.45MB/s]
# Extracting noise files for - (living)
# ...
# noise_dataset/DWASHING_16k.zip: 102MB [00:10, 10.2MB/s]
# Extracting noise files for - (washing)
# ...
# noise_dataset/NFIELD_16k.zip: 86.5MB [00:06, 12.9MB/s]
# Extracting noise files for - (field)
# ...
# noise_dataset/NPARK_16k.zip: 86.0MB [00:06, 13.8MB/s]
# Extracting noise files for - (park)
# ...
# noise_dataset/NRIVER_16k.zip: 98.7MB [00:06, 14.2MB/s]
# Extracting noise files for - (river)
# ...
# noise_dataset/OMEETING_16k.zip: 82.7MB [00:05, 14.2MB/s]
# Extracting noise files for - (hallway)
# ...
# noise_dataset/OMEETING_16k.zip: 82.7MB [00:10, 8.06MB/s]
# Extracting noise files for - (meeting)
# ...
# noise_dataset/OOFFICE_16k.zip: 89.0MB [00:16, 5.45MB/s]
# Extracting noise files for - (office)
# ...
# noise_dataset/PCAFETER_16k.zip: 107MB [00:12, 8.30MB/s]
# Extracting noise files for - (cafeter)
# ...

# %%
cd SpeakerProfiling/
# Out:
# /content/SpeakerProfiling

# %% [markdown]
# ## Prepare dataset for training

# %%
# !python prepare_timit_data.py --path='/content/dataset'
# Out:
# Wav Data saved at  /content/dataset/wav_data

# %% [markdown]
# # Training

# %% [markdown]
# Edit config.py with data path or add as arguments

# %%
# !python train_timit.py --data_path='/content/dataset/wav_data' --speaker_csv_path='/content/SpeakerProfiling/Dataset/data_info_height_age.csv' --noise_dataset_path='/content/noise_dataset' --n_workers=2
# Out:
# Training Model on TIMIT Dataset
# #Cores = 2	#GPU = -1
# Dataset Split (Train, Validation, Test)= 3920 700 1680
# Model Details: #Params = 6125187	#Trainable Params = 872067
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# 2021-04-27 18:59:34.581829: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
#
#   | Name                     | Type              | Params
# ---------------------------------------------------------------
# 0 | model                    | Wav2VecLSTM       | 6.1 M
# 1 | classification_criterion | MeanSquaredError  | 0
# 2 | regression_criterion     | MeanSquaredError  | 0
# 3 | mae_criterion            | MeanAbsoluteError | 0
# 4 | rmse_criterion           | RMSELoss          | 0
# 5 | accuracy                 | Accuracy          | 0
# ---------------------------------------------------------------
# ...

# %% [markdown]
# ## Test the trained model
#
# add the path to last saved model checkpoint

# %%
# !python test_timit_fulllen.py --model_checkpoint='TIMIT_logs/version_2/checkpoints/epoch=14-step=404.ckpt' --data_path='/content/dataset/wav_data' --speaker_csv_path='/content/SpeakerProfiling/Dataset/data_info_height_age.csv'
# Out:
# Testing Model on NISP Dataset
# #Cores = 4	#GPU = -1
# Model Details: #Params = 6125187	#Trainable Params = 872067
# 100% 1680/1680 [06:57<00:00,  4.02it/s]
# 7.64642254749009 5.640302940913609 7.532212119936873 5.553227997643607
# 6.300563252487424 5.030599239894321 8.564632168651302 5.926230130604335
# 0.9928571428571429
